# %% [markdown]
# # Advances in Machine Learning with Big Data
#
# ### Jeremy Large
# #### jeremy.large@economics.ox.ac.uk
#
#
# &#169; Jeremy Large ; shared under [CC BY-NC-ND 4.0](https://creativecommons.org/licenses/by-nc-nd/4.0/)

# %% [markdown]
# ## 2. Being an econometrician *and* a data scientist

# %% [markdown]
# ## Contents Weeks 1-4:
#
# 1. Introducing this course's dataset
#
# 1. **Being an econometrician _and_ a data scientist**
#
# 1. Overfit and regularization
#
# 1. Regularization through predictor/feature selection (Lasso etc.)
#
# 1. Resampling methods, and model selection
#
# 1. Decision trees, bagging, and random forests
#
# 1. Single-layer neural networks

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
plt.rcParams['figure.figsize'] = [12, 4]

import sys, os
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO)

# point at library; I need some lessons on doing good PYTHONPATHs:
REPO_DIR = os.path.dirname(os.getcwd())

UCI_LIB = os.path.join(REPO_DIR, 'lib')
UCI_DATA = os.path.join(REPO_DIR, 'data') 

sys.path.append(UCI_LIB)

UCI_DATA_FILE = os.path.join(UCI_DATA, 'raw.csv') 

from uci_retail_data import stock_codes, uci_files
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Pull in and prepare our data

# %%
if os.path.exists(UCI_DATA_FILE):
    df = uci_files.load_uci_file(UCI_DATA_FILE, uci_files.SHEET_NAME)
else:
    df = uci_files.load_uci_file(uci_files.REMOTE_FILE, uci_files.SHEET_NAME)
    df.to_csv(UCI_DATA_FILE)
    logging.info('Saving a copy to ' + UCI_DATA_FILE)
# Out:
# 2021-04-30 10:43:05,832 INFO:Loading C:\Users\zomma\Documents\GitHub\ox-sbs-ml-bd\data\raw.csv , sheet Year 2009-2010
# 2021-04-30 10:43:08,094 INFO:Loaded C:\Users\zomma\Documents\GitHub\ox-sbs-ml-bd\data\raw.csv , sheet number one, obviously

# %% [markdown]
# Clean data:

# %%
# Here, I call the irrelevant lines 'invalids':
invalids = stock_codes.invalid_series(df)

# %% [markdown]
# Aggregate into invoices:

# %%
invoices = stock_codes.invoice_df(df, invalid_series=invalids)
# Out:
# 2021-04-30 10:43:25,440 INFO:NumExpr defaulting to 8 threads.

# %%
invoices.head(2)
# Out:
#          customer  codes_in_invoice  items_in_invoice  invoice_spend  hour  \
# Invoice
# 489434    13085.0                 8               166          505.3     7
# 489435    13085.0                 4                60          145.8     7
#
#           month                                              words  \
# Invoice
# 489434   200912  {SWEET, SINGLE, BOX, FONT, HOME, SIZE, PINK, M...
# 489435   200912  {CAT, LUNCHBOX, HEART, WITH, BOWL, LARGE, CUTL...
#
#                 country  words_per_item
# Invoice
# 489434   United Kingdom           3.625
# 489435   United Kingdom           4.000

# %%
invoices.tail(2)
# Out:
#          customer  codes_in_invoice  items_in_invoice  invoice_spend  hour  \
# Invoice
# 538170    13969.0                25               133         317.59    19
# 538171    17530.0                65               194         300.64    20
#
#           month                                              words  \
# Invoice
# 538170   201012  {AREA, HOUSE, FAWN, BAKELIKE, LARGE, HOT, KNIT...
# 538171   201012  {BOX, ABSTRACT, SETTING, 72, PINK, GARDEN, FAI...
#
#                 country  words_per_item
# Invoice
# 538170   United Kingdom            2.92
# 538171   United Kingdom            2.20

# %%
invoices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20577 entries, 489434 to 538171
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer          18969 non-null  float64
#  1   codes_in_invoice  20577 non-null  int64
#  2   items_in_invoice  20577 non-null  int64
#  3   invoice_spend     20577 non-null  float64
#  4   hour              20577 non-null  int64
#  5   month             20577 non-null  int64
#  6   words             20577 non-null  object
#  7   country           20577 non-null  object
#  8   words_per_item    20577 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Set a prediction problem:

# %% [markdown]
# **Given the time, date, and complexity of an invoice, what's its expected spend per item shipped?**
#
# > *helps us predict margins*

# %% [markdown]
# Note:
#
# * This is a [supervised](https://en.wikipedia.org/wiki/Machine_learning#Machine_learning_approaches) problem
#
# * It is also a regression problem, rather than [classification](https://en.wikipedia.org/wiki/Statistical_classification)
#
# These will be boundaries to this course.

# %% [markdown]
# First, we'll attack this in a familiar way: using, as best we can, *linear regression*.
#
# *  However, we'll take time to compare two suitable `python` libraries for this.

# %% [markdown]
# ### 1. [`statsmodels`](https://www.statsmodels.org/stable/index.html)
#
# * package for established statistics; has [some of the feel](https://www.statsmodels.org/stable/example_formulas.html) of R
#
# * *statsmodels: Econometric and statistical modeling with python* Seabold, Skipper, and Josef Perktold. Proceedings of the 9th Python in Science Conference, 2010.
#
# * funded at [Google Summer of Code (GSOC) 2009-2017](https://summerofcode.withgoogle.com/) and by hedge fund [AQR](https://www.aqr.com)

# %% [markdown]
# ### 2. [`scikit-learn`](https://scikit-learn.org/stable/index.html)
#
# * package for machine learning
#
# * *Scikit-learn: Machine Learning in Python*, Pedregosa et al., JMLR 12, pp. 2825-2830, 2011.
#
# They both do linear regression.

# %% [raw]
# Note - here's the bibtex references for scikit-learn and for statsmodels:
#
# @article{scikit-learn,
#  title={Scikit-learn: Machine Learning in {P}ython},
#  author={Pedregosa, F. and Varoquaux, G. and Gramfort, A. and Michel, V.
#          and Thirion, B. and Grisel, O. and Blondel, M. and Prettenhofer, P.
#          and Weiss, R. and Dubourg, V. and Vanderplas, J. and Passos, A. and
#          Cournapeau, D. and Brucher, M. and Perrot, M. and Duchesnay, E.},
#  journal={Journal of Machine Learning Research},
#  volume={12},
#  pages={2825--2830},
#  year={2011}
# }
#
# @inproceedings{seabold2010statsmodels,
#   title={statsmodels: Econometric and statistical modeling with python},
#   author={Seabold, Skipper and Perktold, Josef},
#   booktitle={9th Python in Science Conference},
#   year={2010},
# }

# %% [markdown]
# #### Lets import statsmodels / scikit-learn and packages that they use:

# %%
import numpy as np    # fast handling of matrices of real numbers, and similar

import pandas as pd     # great tool for wielding and combining rectangular datasets with varied, named, columns



import sklearn

import statsmodels

# %%
# in both cases, we will have to import specifically the bits of the package that we need, for example:
import statsmodels.formula.api as smf

# %% [markdown]
# #### Reminder of linear regression:

# %% [markdown]
# We have an i.i.d. sequence of observations, $\{(y_i, x_i), i=0, 1, ...\}$ where we are interested in moments of the R.V. $y_i$, conditional on the multivariate R.V.  $x_i$ (of length, say, $p$).
#
# We *postulate* a linear relationship of the following form:
#
# \begin{equation}
# y_i = x_i ' \beta + \epsilon_i,
# \end{equation}
# where $\beta$ is a vector of parameters of length $p$, and the i.i.d. sequence of random variables $\{\epsilon_i\}$ is independent of the regressors $\{x_i\}$

# %% [markdown]
# #### A personal story:
#
# Now, what do I mean here by the word: *'postulate'*?
#
# For the econometrician in me, it means I *sincerely assert*.
#
# For the machine learner in me, I'm not sure that's quite it. It's more that - pragmatically - I entertain this model.
#
# * an important part of this course will be to flesh-out this comparison

# %% [markdown]
# **Exercise/reading**: [Breiman](https://projecteuclid.org/euclid.ss/1009213726#ui-tabs-1) formulates something like this as *Data modelling* versus *Algorithmic modelling*. Take a look and prepare to discuss in class.

# %% [markdown]
# ### 1. Fitting a linear regression with `statsmodels`
#
# Describe the model in natural statistician's terms:

# %%
formula_string = 'np.log(invoice_spend/items_in_invoice) ~ np.log(codes_in_invoice) + hour + month + words_per_item'

# %% [markdown]
# Specify that the model is OLS:

# %%
lm1 = smf.ols(formula=formula_string, data=invoices)

# %% [markdown]
# Common, pythonic, step, next, namely to `fit()`:

# %%
fit = lm1.fit()

# %%
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        OLS Regression Results
# ====================================================================================================
# Dep. Variable:     np.log(invoice_spend / items_in_invoice)   R-squared:                       0.021
# Model:                                                  OLS   Adj. R-squared:                  0.021
# Method:                                       Least Squares   F-statistic:                     109.0
# Date:                                      Fri, 30 Apr 2021   Prob (F-statistic):           4.55e-92
# Time:                                              10:54:09   Log-Likelihood:                -19801.
# No. Observations:                                     20577   AIC:                         3.961e+04
# Df Residuals:                                         20572   BIC:                         3.965e+04
# Df Model:                                                 4
# Covariance Type:                                  nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   50.6791     34.101      1.486      0.137     -16.161     117.519
# np.log(codes_in_invoice)    -0.0378      0.005     -7.717      0.000      -0.047      -0.028
# hour                         0.0059      0.002      3.213      0.001       0.002       0.010
# month                       -0.0002      0.000     -1.470      0.142      -0.001    8.32e-05
# words_per_item               0.0633      0.007      8.681      0.000       0.049       0.078
# ==============================================================================
# Omnibus:                     2976.262   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21367.662
# Skew:                           0.495   Prob(JB):                         0.00
# Kurtosis:                       7.893   Cond. No.                     1.55e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The 'condition number' refers to $X'X$ -- and indicates how stably we can expect to invert that matrix

# %% [markdown]
# #### Comments on linear regression with `statsmodels`
#
# * Thorough implementation of linear regression, elegant presentation, including tests:
#     * significance tests (t-stats, F-tests, p-values, ...)
#     * specification tests

# %% [markdown]
# * Imagine these tests pass (though they don't here)
#     * we may conclude that we now *know* the Data Generating Process
#        * our parametric modelling has been successful
#     * we understand statistical aspects of the mechanisms out there
#     * -> we are in a position to offer *explanations* of past, present and future observation

# %% [markdown]
# * However, standard reporting from `statsmodels` is fairly negative for my specifiation of the linear regression model on this data
#     * Message: this is not much use, come back with something that describes reality better

# %% [markdown]
# * All the data has been used in fitting the regression
#     * like e.g. MLEs, resulting estimates are statistically *efficient*.
#     * But, to use up all the data like that:
#       * was that greedy?
#       * was it prudent?

# %% [markdown]
# ### 2. Fitting a linear regression with `scikit-learn`
#
# In the case of `scikit-learn`, there are preliminaries to go over.

# %%
# Reminder of our formulation of this regression:
formula_string
# Out:
# 'np.log(invoice_spend/items_in_invoice) ~ np.log(codes_in_invoice) + hour + month + words_per_item'

# %%
#  First, we'll have to build some additional columns in our dataframe to do logariths etc.:
invoices['log_item_spend'] = np.log(invoices.invoice_spend / invoices.items_in_invoice)
invoices['log_n_codes'] = np.log(invoices.codes_in_invoice)

# %%
# Regarding this, set out `y` and `X` variables:
y = pd.DataFrame(invoices['log_item_spend'])
X = invoices[['log_n_codes', 'hour', 'month', 'words_per_item']]

# %%
#  pull in scikit-learn libraries:
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()

# %% [markdown]
# #### `.fit()` - first of two central functions/methods in `scikit-learn`

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### `.predict()` - the second of the two

# %%
y_hat = model.predict(X)
plt.scatter(y_hat, y, marker='.')
plt.grid(); plt.xlabel('fit'); plt.ylabel('actual'); plt.axvline(); plt.axhline(); plt.show()

# %%
print('intercept is ', model.intercept_)
print('coefficients are ', model.coef_)
print('R2 is ', model.score(X, y))
print('MSE of prediction is', metrics.mean_squared_error(model.predict(X), y))
# Out:
# intercept is  [50.67914996]
# coefficients are  [[-0.03775424  0.00592188 -0.0002493   0.06332345]]
# R2 is  0.02075104873480338
# MSE of prediction is 0.4012000071461238

# %% [markdown]
# We note that the Mean Square Error of the target, anyway, is:

# %%
np.round(invoices.log_item_spend.var(), 4)
# Out:
# 0.4097

# %% [markdown]
# -> We can confirm by checking back that these are the same numbers as those obtained earlier with `statsmodels`

# %% [markdown]
# #### Observations so far about linear regression with `scikit-learn`
#
# The linear regression feels much less slick than `statsmodels`
#
# * we have to do more work to prepare it
#
# * it only presents the details of its fit, if we interrogate oddly-named attributes like `.coef_`
#
# * it doesn't seem to offer either specification, or significance, testing
#
# In fact, it seems hard to extract from it anything much at all, relating to its *linear* structure

# %% [markdown]
# #### Lets push `scikit-learn` harder, to find out where it excels

# %% [markdown]
# #### Separate testing data from training data: the [KFold split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
from sklearn.model_selection import KFold

# %% [markdown]
# *Introduction to Statistical Learning* 5.1.3

# %% [markdown]
# #### We're going to loop through data, so we write a function to encapsulate that:

# %% [markdown]
# Take a look at [`train_n_test()`](https://github.com/jeremy-large/ox-sbs-ml-bd/blob/master/lib/sbs_sklearn.py#L21)

# %%
from sbs_sklearn import train_n_test

# %% [markdown]
# #### ... and a helper function to plot diagrams:

# %% [markdown]
# Take a look at [`plot_kfold_scores()`](https://github.com/jeremy-large/ox-sbs-ml-bd/blob/master/lib/sbs_sklearn.py#L66)

# %%
from sbs_sklearn import plot_kfold_scores

# %% [markdown]
# #### Now lets deploy `scikit-learn` several times, distinguishing `train` from `test`:

# %%
scores = train_n_test(X, y, 6, update_frequency=1, concise=False)
# Out:
# 2021-04-30 11:13:00,957 INFO:In study 1/6, train on 17147 randomly selected points; then test on the other 3430: first few test points = [21 29 34 41 42]
# 2021-04-30 11:13:00,965 INFO:In study 2/6, train on 17147 randomly selected points; then test on the other 3430: first few test points = [ 7 10 16 22 31]
# 2021-04-30 11:13:00,978 INFO:In study 3/6, train on 17147 randomly selected points; then test on the other 3430: first few test points = [13 20 23 24 32]
# 2021-04-30 11:13:00,988 INFO:In study 4/6, train on 17148 randomly selected points; then test on the other 3429: first few test points = [ 2  3 11 12 14]
# 2021-04-30 11:13:00,999 INFO:In study 5/6, train on 17148 randomly selected points; then test on the other 3429: first few test points = [ 0  4  8 17 27]
# 2021-04-30 11:13:01,011 INFO:In study 6/6, train on 17148 randomly selected points; then test on the other 3429: first few test points = [ 1  5  6  9 19]

# %%
plot_kfold_scores(scores)

# %%
scores = train_n_test(X, y, 750)
plot_kfold_scores(scores, scatter=True)
# Out:
# 2021-04-30 11:13:03,646 INFO:Study 1/750: 20549 train rows;  28 test rows

# %%
plot_kfold_scores(scores)

# %% [markdown]
# ### Comments on linear regression with `scikit-learn`
#
# * Correct implementation of linear regression
#
# * Not focused on standard testing for linear regression
#     * significance tests (t-stats, F-tests, p-values, ...)
#     * specification tests

# %% [markdown]
# * Our model failed every specification test that `statsmodel` threw at it
#
# * -> YET (per `scikit-learn`): it had a decent r2 on unseen data
#     * Pragmatism: this model, for all its faults, can be used

# %% [markdown]
# * To embody more of a Machine Learning paradigm, we reprioritize:
#     * prediction [`.predict() `] as compared to explanation
#     * out-of-sample testing, as compared to specification testing
#     * empirical distribution of our statistic, as compared to an asymptotic limit theory for it

# %% [markdown]
# To embody more of a Machine Learning paradigm, we reprioritize:
# * prediction [`.predict() `] as compared to explanation
# * out-of-sample testing, as compared to specification testing
# * empirical distribution of our statistic, as compared to an asymptotic limit theory for it

# %% [markdown]
# ### > In an abundance of data, and for some purposes, this reprioritization will make sense
#
# * leaves us flexible in new dimensions

# %% [markdown]
# **Exercise**: apply the K-fold regression approach with number of folds equal to a tenth of the number of observations. Plot a histogram of the result, and discuss its meaning, as well as why it takes so long to compute.

# %%
folds_10 = int(round(X.shape[0] / 10, 0))

# %%
folds_10
# Out:
# 2058

# %%
scores10 = train_n_test(X, y, folds_10, update_frequency=1, concise=False)
# Out:
# 2021-04-30 11:14:43,200 INFO:In study 1/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3104  3481  5795 10637 11538]
# 2021-04-30 11:14:43,207 INFO:In study 2/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 497 1539 1632 4510 7253]
# 2021-04-30 11:14:43,215 INFO:In study 3/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1412 2711 4598 5936 6273]
# 2021-04-30 11:14:43,223 INFO:In study 4/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  768  6026  6538  9758 11531]
# 2021-04-30 11:14:43,235 INFO:In study 5/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1114 3822 3833 4500 4551]
# 2021-04-30 11:14:43,243 INFO:In study 6/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 388  680  919 1361 4837]
# 2021-04-30 11:14:43,253 INFO:In study 7/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2163  3230  5340  9605 11623]
# 2021-04-30 11:14:43,263 INFO:In study 8/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 808 4600 6318 6375 7055]
# 2021-04-30 11:14:43,270 INFO:In study 9/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 165  730 7319 8705 9481]
# 2021-04-30 11:14:43,279 INFO:In study 10/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1467 2063 3587 4688 8023]
# 2021-04-30 11:14:43,292 INFO:In study 11/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2187  4047  7209  7486 12194]
# 2021-04-30 11:14:43,301 INFO:In study 12/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 567 1379 6016 7069 8291]
# 2021-04-30 11:14:43,308 INFO:In study 13/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1574 3090 6236 6437 9108]
# 2021-04-30 11:14:43,317 INFO:In study 14/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1079 1881 3845 7203 7880]
# 2021-04-30 11:14:43,328 INFO:In study 15/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6064  7446  8053 10308 10579]
# 2021-04-30 11:14:43,337 INFO:In study 16/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3948  4403  6119  6931 10614]
# 2021-04-30 11:14:43,350 INFO:In study 17/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 242 1558 1601 2614 7080]
# 2021-04-30 11:14:43,362 INFO:In study 18/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1464 2484 4730 4940 8164]
# 2021-04-30 11:14:43,372 INFO:In study 19/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   5 2040 3965 5243 7393]
# 2021-04-30 11:14:43,379 INFO:In study 20/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3726 4200 4645 5521 8085]
# 2021-04-30 11:14:43,392 INFO:In study 21/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5976  5997  7121  7696 14504]
# 2021-04-30 11:14:43,402 INFO:In study 22/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1512 6017 8327 8716 8982]
# 2021-04-30 11:14:43,414 INFO:In study 23/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  421  1267  6612 10831 11282]
# 2021-04-30 11:14:43,425 INFO:In study 24/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   57   645 11318 11555 12121]
# 2021-04-30 11:14:43,438 INFO:In study 25/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3325 5259 5335 5712 6957]
# 2021-04-30 11:14:43,445 INFO:In study 26/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4184 5042 5319 7234 7342]
# 2021-04-30 11:14:43,457 INFO:In study 27/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 487 3754 4812 6462 7505]
# 2021-04-30 11:14:43,464 INFO:In study 28/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 281 3450 4065 6591 7373]
# 2021-04-30 11:14:43,474 INFO:In study 29/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 509 1209 3088 4245 8775]
# 2021-04-30 11:14:43,485 INFO:In study 30/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 9193 10177 10328 10806 13706]
# 2021-04-30 11:14:43,498 INFO:In study 31/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 110  308 2165 3238 3548]
# 2021-04-30 11:14:43,509 INFO:In study 32/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1649 2166 2840 3698 4936]
# 2021-04-30 11:14:43,517 INFO:In study 33/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 276 2255 4547 6821 9829]
# 2021-04-30 11:14:43,525 INFO:In study 34/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 800  830  999 2858 3113]
# 2021-04-30 11:14:43,538 INFO:In study 35/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  227  3268  5164 10173 10510]
# 2021-04-30 11:14:43,546 INFO:In study 36/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1212 4871 5572 7597 8071]
# 2021-04-30 11:14:43,560 INFO:In study 37/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4531  6666  7947 12501 12744]
# 2021-04-30 11:14:43,570 INFO:In study 38/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  432  4863  5998  9015 10904]
# 2021-04-30 11:14:43,578 INFO:In study 39/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 101 1160 1192 1609 3059]
# 2021-04-30 11:14:43,591 INFO:In study 40/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  908  5046  5125  8461 11849]
# 2021-04-30 11:14:43,598 INFO:In study 41/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 743 2167 3147 4055 7419]
# 2021-04-30 11:14:43,604 INFO:In study 42/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [5658 5886 6181 8027 9215]
# 2021-04-30 11:14:43,614 INFO:In study 43/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1492 1803 3817 6012 7402]
# 2021-04-30 11:14:43,627 INFO:In study 44/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1420  1909  5397  6221 10578]
# 2021-04-30 11:14:43,637 INFO:In study 45/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [6615 7971 8601 9072 9633]
# 2021-04-30 11:14:43,646 INFO:In study 46/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6200  7622  7850  9582 11219]
# 2021-04-30 11:14:43,658 INFO:In study 47/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 770 1156 1571 2116 2654]
# 2021-04-30 11:14:43,667 INFO:In study 48/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 443 1522 4060 4735 4855]
# 2021-04-30 11:14:43,674 INFO:In study 49/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 488  491 2077 2754 6326]
# 2021-04-30 11:14:43,683 INFO:In study 50/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 115  295  304 3871 4558]
# 2021-04-30 11:14:43,691 INFO:In study 51/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 544 5004 6799 6863 7376]
# 2021-04-30 11:14:43,697 INFO:In study 52/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  91  742 2627 6485 7003]
# 2021-04-30 11:14:43,708 INFO:In study 53/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2348 4092 5489 6023 8136]
# 2021-04-30 11:14:43,715 INFO:In study 54/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1707 1762 3021 4853 5330]
# 2021-04-30 11:14:43,724 INFO:In study 55/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2886  3487  5411  7156 10246]
# 2021-04-30 11:14:43,736 INFO:In study 56/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1118  1249  2061  4959 10928]
# 2021-04-30 11:14:43,743 INFO:In study 57/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  368  2477  6421  8120 13146]
# 2021-04-30 11:14:43,753 INFO:In study 58/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  957  4586  5157  6843 12455]
# 2021-04-30 11:14:43,766 INFO:In study 59/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1828 4667 8529 8660 9995]
# 2021-04-30 11:14:43,776 INFO:In study 60/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  15 1259 3959 8204 8307]
# 2021-04-30 11:14:43,784 INFO:In study 61/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 486 1533 2270 3880 6420]
# 2021-04-30 11:14:43,797 INFO:In study 62/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1455  7644  8827  9426 13730]
# 2021-04-30 11:14:43,810 INFO:In study 63/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 659 1787 2244 3731 7789]
# 2021-04-30 11:14:43,820 INFO:In study 64/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4135  4605  6569  9958 12515]
# 2021-04-30 11:14:43,827 INFO:In study 65/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4563 4722 6606 8047 8232]
# 2021-04-30 11:14:43,836 INFO:In study 66/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  264  5200  5256  8718 14882]
# 2021-04-30 11:14:43,849 INFO:In study 67/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   33  4527  5731 11783 12427]
# 2021-04-30 11:14:43,857 INFO:In study 68/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1900  3396  4164  7832 10074]
# 2021-04-30 11:14:43,865 INFO:In study 69/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2340  4474  5759  8490 12256]
# 2021-04-30 11:14:43,872 INFO:In study 70/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 145 7090 7416 8440 9188]
# 2021-04-30 11:14:43,879 INFO:In study 71/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4873 5501 5942 8290 9123]
# 2021-04-30 11:14:43,892 INFO:In study 72/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3434  9285  9548 12925 15689]
# 2021-04-30 11:14:43,900 INFO:In study 73/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 836 2753 3403 6373 8758]
# 2021-04-30 11:14:43,909 INFO:In study 74/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 576 1205 5316 6751 7235]
# 2021-04-30 11:14:43,922 INFO:In study 75/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2810 3004 3157 4658 5372]
# 2021-04-30 11:14:43,932 INFO:In study 76/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 470 5924 9381 9608 9655]
# 2021-04-30 11:14:43,941 INFO:In study 77/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2573  6037  7860 10353 10423]
# 2021-04-30 11:14:43,949 INFO:In study 78/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 726 3752 6377 6640 7742]
# 2021-04-30 11:14:43,956 INFO:In study 79/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [5745 7114 7307 7563 9494]
# 2021-04-30 11:14:43,963 INFO:In study 80/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 8757  9402 12563 13750 13967]
# 2021-04-30 11:14:43,975 INFO:In study 81/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2645 3608 4665 6756 6899]
# 2021-04-30 11:14:43,981 INFO:In study 82/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  223  2953  4541  5002 13903]
# 2021-04-30 11:14:43,991 INFO:In study 83/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  95 2958 3161 3941 7144]
# 2021-04-30 11:14:43,998 INFO:In study 84/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1545 12429 14187 14282 14793]
# 2021-04-30 11:14:44,008 INFO:In study 85/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2720 2768 4496 7082 7855]
# 2021-04-30 11:14:44,021 INFO:In study 86/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 554 3818 4751 6546 8287]
# 2021-04-30 11:14:44,031 INFO:In study 87/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  397   849  2971  6574 11462]
# 2021-04-30 11:14:44,040 INFO:In study 88/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2240 3610 4728 4742 8564]
# 2021-04-30 11:14:44,052 INFO:In study 89/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1795  5037  7161  9289 10073]
# 2021-04-30 11:14:44,059 INFO:In study 90/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  480  1422  5736 11060 12274]
# 2021-04-30 11:14:44,068 INFO:In study 91/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 103 3166 4022 6775 8325]
# 2021-04-30 11:14:44,075 INFO:In study 92/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  23 3229 5587 5648 6305]
# 2021-04-30 11:14:44,082 INFO:In study 93/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1003 2948 5444 5867 6155]
# 2021-04-30 11:14:44,094 INFO:In study 94/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3638  3949  4362  5701 11260]
# 2021-04-30 11:14:44,104 INFO:In study 95/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 759 6249 6958 7687 9917]
# 2021-04-30 11:14:44,112 INFO:In study 96/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3253 3676 4647 8534 8881]
# 2021-04-30 11:14:44,119 INFO:In study 97/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2752 5231 7213 7396 8417]
# 2021-04-30 11:14:44,132 INFO:In study 98/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 234 1220 3417 3453 7123]
# 2021-04-30 11:14:44,144 INFO:In study 99/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2256 2823 4438 4635 5300]
# 2021-04-30 11:14:44,155 INFO:In study 100/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  595  3674  4372  6984 11413]
# 2021-04-30 11:14:44,165 INFO:In study 101/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4435  6027  7317 11186 12205]
# 2021-04-30 11:14:44,174 INFO:In study 102/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1868  3291  4340  5975 14946]
# 2021-04-30 11:14:44,183 INFO:In study 103/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1307  6235  7044 10755 11031]
# 2021-04-30 11:14:44,191 INFO:In study 104/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6890  7292  9119 10649 11922]
# 2021-04-30 11:14:44,203 INFO:In study 105/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4651 6913 7467 7976 8258]
# 2021-04-30 11:14:44,211 INFO:In study 106/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3748  6621 11092 11150 14322]
# 2021-04-30 11:14:44,219 INFO:In study 107/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  490   667   816   962 11861]
# 2021-04-30 11:14:44,227 INFO:In study 108/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1190 2141 4183 6997 7658]
# 2021-04-30 11:14:44,237 INFO:In study 109/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5686  6146 10088 11127 11791]
# 2021-04-30 11:14:44,246 INFO:In study 110/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1493  2072  4715  6714 10696]
# 2021-04-30 11:14:44,255 INFO:In study 111/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1388 5799 7092 7272 9286]
# 2021-04-30 11:14:44,262 INFO:In study 112/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 474 1015 2053 3586 4629]
# 2021-04-30 11:14:44,269 INFO:In study 113/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 598  910 4680 5276 5645]
# 2021-04-30 11:14:44,279 INFO:In study 114/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 309 1660 1763 2807 5566]
# 2021-04-30 11:14:44,291 INFO:In study 115/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  790  5085  7972  8515 11314]
# 2021-04-30 11:14:44,298 INFO:In study 116/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 689 4150 4486 7239 7442]
# 2021-04-30 11:14:44,306 INFO:In study 117/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1107  6283 10226 11803 13171]
# 2021-04-30 11:14:44,319 INFO:In study 118/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  715  2907  5539  7617 14716]
# 2021-04-30 11:14:44,329 INFO:In study 119/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 222 1877 3404 7979 8661]
# 2021-04-30 11:14:44,338 INFO:In study 120/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 180  906 1135 1223 6680]
# 2021-04-30 11:14:44,345 INFO:In study 121/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1945  3083  3596  9173 12277]
# 2021-04-30 11:14:44,356 INFO:In study 122/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3032 4397 6191 6921 9097]
# 2021-04-30 11:14:44,367 INFO:In study 123/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1371 1761 1788 3468 5535]
# 2021-04-30 11:14:44,374 INFO:In study 124/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1292  3565  5910  9160 11053]
# 2021-04-30 11:14:44,383 INFO:In study 125/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1011  3318  5293 10631 11543]
# 2021-04-30 11:14:44,391 INFO:In study 126/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1326 1560 7198 7950 9920]
# 2021-04-30 11:14:44,401 INFO:In study 127/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [    8  3227  8545 10763 11787]
# 2021-04-30 11:14:44,408 INFO:In study 128/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 954 1797 2935 6856 7517]
# 2021-04-30 11:14:44,415 INFO:In study 129/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6278  6391  9221  9352 11352]
# 2021-04-30 11:14:44,423 INFO:In study 130/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 391 6509 9034 9201 9252]
# 2021-04-30 11:14:44,432 INFO:In study 131/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 817 1170 4021 4075 5775]
# 2021-04-30 11:14:44,444 INFO:In study 132/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6429  8944 11877 15464 15752]
# 2021-04-30 11:14:44,452 INFO:In study 133/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 298 3886 4240 6468 6760]
# 2021-04-30 11:14:44,460 INFO:In study 134/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  738  1917  9968 10692 11280]
# 2021-04-30 11:14:44,471 INFO:In study 135/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1175 2290 2587 3222 7840]
# 2021-04-30 11:14:44,484 INFO:In study 136/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1382 2205 2338 5096 6433]
# 2021-04-30 11:14:44,494 INFO:In study 137/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1070  3636  8994 12369 13830]
# 2021-04-30 11:14:44,501 INFO:In study 138/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 216 2417 3350 4108 7414]
# 2021-04-30 11:14:44,509 INFO:In study 139/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 332 2615 4308 5622 7654]
# 2021-04-30 11:14:44,519 INFO:In study 140/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4992 6021 7042 8242 8297]
# 2021-04-30 11:14:44,526 INFO:In study 141/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 585  684 1019 3163 5210]
# 2021-04-30 11:14:44,535 INFO:In study 142/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3293 3757 4780 5108 7032]
# 2021-04-30 11:14:44,548 INFO:In study 143/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 737 2677 3624 4552 6208]
# 2021-04-30 11:14:44,555 INFO:In study 144/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   0  621 1605 2435 2821]
# 2021-04-30 11:14:44,567 INFO:In study 145/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2432  6048  6599  7247 10265]
# 2021-04-30 11:14:44,576 INFO:In study 146/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1646  1655  1720  4217 12184]
# 2021-04-30 11:14:44,585 INFO:In study 147/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 445 1722 2507 4887 8884]
# 2021-04-30 11:14:44,593 INFO:In study 148/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   55  1288  5090  8496 14127]
# 2021-04-30 11:14:44,601 INFO:In study 149/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 7726  9585 10050 11892 12478]
# 2021-04-30 11:14:44,610 INFO:In study 150/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2214 4622 4939 6268 9256]
# 2021-04-30 11:14:44,620 INFO:In study 151/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 291 2160 4032 7732 8075]
# 2021-04-30 11:14:44,633 INFO:In study 152/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3269  6784  9226 12106 12146]
# 2021-04-30 11:14:44,643 INFO:In study 153/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 383 1128 3311 4589 7836]
# 2021-04-30 11:14:44,656 INFO:In study 154/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2458 2767 4305 4743 7706]
# 2021-04-30 11:14:44,665 INFO:In study 155/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  402  5360  7364  9129 11448]
# 2021-04-30 11:14:44,674 INFO:In study 156/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3528  4122  4127 12562 13051]
# 2021-04-30 11:14:44,684 INFO:In study 157/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3210 3931 6234 8222 9322]
# 2021-04-30 11:14:44,693 INFO:In study 158/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3406  6662  8125 11184 14945]
# 2021-04-30 11:14:44,700 INFO:In study 159/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1957 2100 3597 6301 8338]
# 2021-04-30 11:14:44,711 INFO:In study 160/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1375 2576 4325 4768 5858]
# 2021-04-30 11:14:44,718 INFO:In study 161/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 179  733  921 3286 5739]
# 2021-04-30 11:14:44,725 INFO:In study 162/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1490 5288 6702 8344 8889]
# 2021-04-30 11:14:44,736 INFO:In study 163/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1978 3162 3717 3963 4778]
# 2021-04-30 11:14:44,744 INFO:In study 164/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3842 4288 5377 6600 7755]
# 2021-04-30 11:14:44,751 INFO:In study 165/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1142 4562 5896 7675 9134]
# 2021-04-30 11:14:44,758 INFO:In study 166/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3618  5580  9807 11027 12599]
# 2021-04-30 11:14:44,766 INFO:In study 167/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 780 5952 6559 7623 8225]
# 2021-04-30 11:14:44,778 INFO:In study 168/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5235  6808  7377 10078 11247]
# 2021-04-30 11:14:44,785 INFO:In study 169/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 7068  8768  8943  9708 14809]
# 2021-04-30 11:14:44,793 INFO:In study 170/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1405 11722 13606 13770 14054]
# 2021-04-30 11:14:44,800 INFO:In study 171/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1278 1658 1765 5523 7277]
# 2021-04-30 11:14:44,809 INFO:In study 172/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  62  867 4908 6179 6358]
# 2021-04-30 11:14:44,819 INFO:In study 173/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [11126 13070 13752 14648 15675]
# 2021-04-30 11:14:44,829 INFO:In study 174/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  49  716 7160 8110 8156]
# 2021-04-30 11:14:44,837 INFO:In study 175/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3946 4128 4441 4539 6183]
# 2021-04-30 11:14:44,849 INFO:In study 176/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1842 2159 2332 3738 5941]
# 2021-04-30 11:14:44,859 INFO:In study 177/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4666 6040 6764 7227 7582]
# 2021-04-30 11:14:44,869 INFO:In study 178/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2931  6039  9666 12344 14353]
# 2021-04-30 11:14:44,879 INFO:In study 179/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 779 2043 3038 4003 6111]
# 2021-04-30 11:14:44,888 INFO:In study 180/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  219  4946  5827 14990 15296]
# 2021-04-30 11:14:44,899 INFO:In study 181/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4249  8286 11375 11546 11764]
# 2021-04-30 11:14:44,911 INFO:In study 182/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 648 2769 2980 4895 8859]
# 2021-04-30 11:14:44,919 INFO:In study 183/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  61 3532 4145 5487 7394]
# 2021-04-30 11:14:44,928 INFO:In study 184/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1948 3750 6242 7601 8200]
# 2021-04-30 11:14:44,936 INFO:In study 185/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 683 1506 2699 8681 9263]
# 2021-04-30 11:14:44,947 INFO:In study 186/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1529  4285  5297  5524 11816]
# 2021-04-30 11:14:44,956 INFO:In study 187/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4464  4634  7664  8953 12374]
# 2021-04-30 11:14:44,964 INFO:In study 188/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1473 1734 2995 3994 6512]
# 2021-04-30 11:14:44,972 INFO:In study 189/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2963  3204  4752  5505 14455]
# 2021-04-30 11:14:44,984 INFO:In study 190/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 555 2298 2811 5874 9342]
# 2021-04-30 11:14:44,992 INFO:In study 191/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 317  342 6566 6848 8669]
# 2021-04-30 11:14:45,005 INFO:In study 192/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 229 2149 4874 5168 9016]
# 2021-04-30 11:14:45,018 INFO:In study 193/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2928  4462  6545  8648 12581]
# 2021-04-30 11:14:45,027 INFO:In study 194/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2242 2982 7569 8830 9213]
# 2021-04-30 11:14:45,038 INFO:In study 195/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1672  2123  8348  9977 11208]
# 2021-04-30 11:14:45,048 INFO:In study 196/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2781 5239 6263 9033 9592]
# 2021-04-30 11:14:45,058 INFO:In study 197/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 438  639 7544 7760 8042]
# 2021-04-30 11:14:45,069 INFO:In study 198/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 813 1381 2114 4614 6382]
# 2021-04-30 11:14:45,077 INFO:In study 199/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 166  944 1718 3602 9854]
# 2021-04-30 11:14:45,090 INFO:In study 200/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1302 2652 3894 4434 8773]
# 2021-04-30 11:14:45,101 INFO:In study 201/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1817  6161  8991  9413 10895]
# 2021-04-30 11:14:45,111 INFO:In study 202/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 806 4797 5195 5358 7788]
# 2021-04-30 11:14:45,124 INFO:In study 203/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 941 2146 2171 5628 8421]
# 2021-04-30 11:14:45,133 INFO:In study 204/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2057  4942  6868  7551 11220]
# 2021-04-30 11:14:45,141 INFO:In study 205/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5401  5468 10680 11207 12406]
# 2021-04-30 11:14:45,152 INFO:In study 206/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3154  4251  6649  8382 10136]
# 2021-04-30 11:14:45,161 INFO:In study 207/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1686  3188  3988  8696 14337]
# 2021-04-30 11:14:45,171 INFO:In study 208/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2700 2726 5241 5668 6746]
# 2021-04-30 11:14:45,179 INFO:In study 209/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4792  6865  9130 10791 12336]
# 2021-04-30 11:14:45,191 INFO:In study 210/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1745 4039 7191 8000 8631]
# 2021-04-30 11:14:45,199 INFO:In study 211/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  58  678  982 5912 8793]
# 2021-04-30 11:14:45,207 INFO:In study 212/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2999  5417  6904  9925 10052]
# 2021-04-30 11:14:45,218 INFO:In study 213/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2927 4083 4756 5763 6195]
# 2021-04-30 11:14:45,229 INFO:In study 214/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  54 1811 3196 5146 6006]
# 2021-04-30 11:14:45,238 INFO:In study 215/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [5498 7401 7797 9663 9677]
# 2021-04-30 11:14:45,245 INFO:In study 216/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 477 1159 4694 5391 7669]
# 2021-04-30 11:14:45,252 INFO:In study 217/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 984 1126 2323 6723 7933]
# 2021-04-30 11:14:45,261 INFO:In study 218/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2511  7428  7681 11241 15930]
# 2021-04-30 11:14:45,273 INFO:In study 219/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 691  928 1833 3243 5130]
# 2021-04-30 11:14:45,285 INFO:In study 220/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 287  494 2549 2635 3686]
# 2021-04-30 11:14:45,298 INFO:In study 221/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  312  5011  6573 11032 12826]
# 2021-04-30 11:14:45,305 INFO:In study 222/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 365 2231 3259 7264 8147]
# 2021-04-30 11:14:45,312 INFO:In study 223/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1312  2118  2319 10211 12770]
# 2021-04-30 11:14:45,319 INFO:In study 224/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4673  9770 10453 10491 11180]
# 2021-04-30 11:14:45,327 INFO:In study 225/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1931 3060 5786 6419 6722]
# 2021-04-30 11:14:45,337 INFO:In study 226/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 7014  7405  8842  9324 10034]
# 2021-04-30 11:14:45,344 INFO:In study 227/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1317  6296  8424  8941 12768]
# 2021-04-30 11:14:45,352 INFO:In study 228/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  213  1179  5142  8197 12048]
# 2021-04-30 11:14:45,359 INFO:In study 229/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4138 4304 5973 6169 7998]
# 2021-04-30 11:14:45,371 INFO:In study 230/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5160  5418  5807 10437 10938]
# 2021-04-30 11:14:45,382 INFO:In study 231/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 226 1714 2642 6426 7512]
# 2021-04-30 11:14:45,390 INFO:In study 232/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  911  5323  6537  6728 12397]
# 2021-04-30 11:14:45,398 INFO:In study 233/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 525 3050 3755 4111 5422]
# 2021-04-30 11:14:45,405 INFO:In study 234/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1880  2709  5249  7037 13131]
# 2021-04-30 11:14:45,412 INFO:In study 235/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  44  200 1582 3030 4867]
# 2021-04-30 11:14:45,425 INFO:In study 236/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2375  5984  6352 11967 13642]
# 2021-04-30 11:14:45,435 INFO:In study 237/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1531 1872 4516 9519 9742]
# 2021-04-30 11:14:45,443 INFO:In study 238/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2932 3115 3160 7218 7648]
# 2021-04-30 11:14:45,450 INFO:In study 239/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1697  2070  3097  9857 12782]
# 2021-04-30 11:14:45,458 INFO:In study 240/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5779  9150 11692 11811 11843]
# 2021-04-30 11:14:45,468 INFO:In study 241/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6762  9540 10204 11078 12408]
# 2021-04-30 11:14:45,479 INFO:In study 242/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2802 5875 6082 6675 7176]
# 2021-04-30 11:14:45,491 INFO:In study 243/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 835  873 4612 5815 7113]
# 2021-04-30 11:14:45,501 INFO:In study 244/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2604  5588 11183 11575 11703]
# 2021-04-30 11:14:45,508 INFO:In study 245/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  546   581  1343  2206 10240]
# 2021-04-30 11:14:45,519 INFO:In study 246/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1245 4487 5280 5574 8694]
# 2021-04-30 11:14:45,528 INFO:In study 247/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 517 2007 2981 4009 7432]
# 2021-04-30 11:14:45,541 INFO:In study 248/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 133 1362 1955 4974 7958]
# 2021-04-30 11:14:45,550 INFO:In study 249/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 105 1081 3078 5466 8713]
# 2021-04-30 11:14:45,559 INFO:In study 250/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1889  2509  6624  8829 11210]
# 2021-04-30 11:14:45,569 INFO:In study 251/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1639 3192 4368 5850 6941]
# 2021-04-30 11:14:45,578 INFO:In study 252/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 455  945 1769 2409 4819]
# 2021-04-30 11:14:45,586 INFO:In study 253/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 629  875 3285 4794 7460]
# 2021-04-30 11:14:45,593 INFO:In study 254/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 721 1630 2451 3449 5413]
# 2021-04-30 11:14:45,601 INFO:In study 255/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  93  940 7154 8029 9588]
# 2021-04-30 11:14:45,613 INFO:In study 256/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1256 3782 5644 9302 9660]
# 2021-04-30 11:14:45,622 INFO:In study 257/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1785 4085 5349 9336 9395]
# 2021-04-30 11:14:45,630 INFO:In study 258/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1633  9111  9971 12332 14677]
# 2021-04-30 11:14:45,643 INFO:In study 259/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1727 2335 6496 7915 8672]
# 2021-04-30 11:14:45,654 INFO:In study 260/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2125 2424 3715 4248 8194]
# 2021-04-30 11:14:45,665 INFO:In study 261/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4884  8312  8507  9262 10793]
# 2021-04-30 11:14:45,676 INFO:In study 262/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1320  3744  6710  9367 11678]
# 2021-04-30 11:14:45,689 INFO:In study 263/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 134  858 1265 4682 5208]
# 2021-04-30 11:14:45,698 INFO:In study 264/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 360 2908 3787 4854 6066]
# 2021-04-30 11:14:45,711 INFO:In study 265/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5589  6415  9103 10879 14431]
# 2021-04-30 11:14:45,720 INFO:In study 266/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1002 1759 1793 3108 4484]
# 2021-04-30 11:14:45,728 INFO:In study 267/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  99  618 3388 5526 6177]
# 2021-04-30 11:14:45,740 INFO:In study 268/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2775  3626  3649  9567 13765]
# 2021-04-30 11:14:45,752 INFO:In study 269/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5395  8939 11635 13053 13883]
# 2021-04-30 11:14:45,761 INFO:In study 270/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1044 4471 5379 5669 8332]
# 2021-04-30 11:14:45,771 INFO:In study 271/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3683  8926 10566 13736 16102]
# 2021-04-30 11:14:45,782 INFO:In study 272/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1441 1717 2789 6171 6966]
# 2021-04-30 11:14:45,795 INFO:In study 273/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1359  4834 11666 13652 15814]
# 2021-04-30 11:14:45,803 INFO:In study 274/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3760  6514  8457  9669 10747]
# 2021-04-30 11:14:45,811 INFO:In study 275/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 796 2019 2879 3545 6379]
# 2021-04-30 11:14:45,823 INFO:In study 276/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [   2 4224 5605 7609 8098]
# 2021-04-30 11:14:45,831 INFO:In study 277/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1242  2277  4928 10091 10900]
# 2021-04-30 11:14:45,838 INFO:In study 278/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5710  7164 10189 12117 14605]
# 2021-04-30 11:14:45,845 INFO:In study 279/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  852  2902  8782  9444 11414]
# 2021-04-30 11:14:45,851 INFO:In study 280/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4163  6749  8706 10162 10718]
# 2021-04-30 11:14:45,858 INFO:In study 281/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1403 1460 2294 6701 7785]
# 2021-04-30 11:14:45,868 INFO:In study 282/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2625  2969  3056  3837 12676]
# ...
# 2021-04-30 11:15:01,449 INFO:In study 1966/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2245 4804 4894 6206 6323]
# 2021-04-30 11:15:01,460 INFO:In study 1967/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1164  6618  9777 13195 13544]
# 2021-04-30 11:15:01,471 INFO:In study 1968/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  704  4350  4729  9614 10771]
# 2021-04-30 11:15:01,482 INFO:In study 1969/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  379  4639  7210  8741 10906]
# 2021-04-30 11:15:01,490 INFO:In study 1970/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 635 3135 5271 6424 8319]
# 2021-04-30 11:15:01,500 INFO:In study 1971/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  510 11267 12663 13097 13551]
# 2021-04-30 11:15:01,512 INFO:In study 1972/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1203  3785  9785 11729 14496]
# 2021-04-30 11:15:01,521 INFO:In study 1973/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2619  7183  7258  8588 13307]
# 2021-04-30 11:15:01,532 INFO:In study 1974/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1394 2384 6140 6384 6893]
# 2021-04-30 11:15:01,542 INFO:In study 1975/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2771  7250  7511 11145 13873]
# 2021-04-30 11:15:01,553 INFO:In study 1976/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2873  6237  7870 11739 12854]
# 2021-04-30 11:15:01,563 INFO:In study 1977/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1130 2168 2959 3815 5115]
# 2021-04-30 11:15:01,574 INFO:In study 1978/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2558  4073  7354  8014 10460]
# 2021-04-30 11:15:01,586 INFO:In study 1979/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5067  7610  7657  8813 11442]
# 2021-04-30 11:15:01,595 INFO:In study 1980/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1790 5755 7131 8369 8567]
# 2021-04-30 11:15:01,608 INFO:In study 1981/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 237 1293 2892 8535 9556]
# 2021-04-30 11:15:01,620 INFO:In study 1982/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  401  3795  8917 11216 16155]
# 2021-04-30 11:15:01,630 INFO:In study 1983/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2393  3659  4502  5382 13474]
# 2021-04-30 11:15:01,641 INFO:In study 1984/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1629  2996  7877  8144 11331]
# 2021-04-30 11:15:01,651 INFO:In study 1985/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 514 2274 6051 7248 8500]
# 2021-04-30 11:15:01,661 INFO:In study 1986/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2618 2685 4100 4418 8244]
# 2021-04-30 11:15:01,671 INFO:In study 1987/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 155  351 2662 2783 4228]
# 2021-04-30 11:15:01,683 INFO:In study 1988/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 6385  9012  9797 11139 11380]
# 2021-04-30 11:15:01,693 INFO:In study 1989/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2473 2693 3093 5111 7271]
# 2021-04-30 11:15:01,703 INFO:In study 1990/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  926  6312 10657 11683 11973]
# 2021-04-30 11:15:01,712 INFO:In study 1991/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1082 1903 2236 6052 7125]
# 2021-04-30 11:15:01,722 INFO:In study 1992/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1031 2112 2763 4263 5272]
# 2021-04-30 11:15:01,733 INFO:In study 1993/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1712 2054 7531 7889 9071]
# 2021-04-30 11:15:01,742 INFO:In study 1994/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3141 3868 4702 7462 7558]
# 2021-04-30 11:15:01,754 INFO:In study 1995/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  97 1471 3841 5511 8189]
# 2021-04-30 11:15:01,763 INFO:In study 1996/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 228 1140 1269 2247 5031]
# 2021-04-30 11:15:01,773 INFO:In study 1997/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4543  6042  7628  7728 11298]
# 2021-04-30 11:15:01,784 INFO:In study 1998/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [    4   224  2844  3616 10351]
# 2021-04-30 11:15:01,792 INFO:In study 1999/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 251  916 1162 1426 5341]
# 2021-04-30 11:15:01,803 INFO:In study 2000/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  197  2285  6507  8949 16266]
# 2021-04-30 11:15:01,815 INFO:In study 2001/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [6970 7896 8001 9157 9856]
# 2021-04-30 11:15:01,826 INFO:In study 2002/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 500 3282 7387 7828 8355]
# 2021-04-30 11:15:01,836 INFO:In study 2003/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 157 2199 4785 6008 7629]
# 2021-04-30 11:15:01,845 INFO:In study 2004/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3844 6084 6464 7570 9471]
# 2021-04-30 11:15:01,855 INFO:In study 2005/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 859 2181 3089 3721 8990]
# 2021-04-30 11:15:01,864 INFO:In study 2006/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2913 4099 7430 8377 8514]
# 2021-04-30 11:15:01,875 INFO:In study 2007/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1470  2602  6717  9555 15414]
# 2021-04-30 11:15:01,883 INFO:In study 2008/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 479 1648 6253 6298 8611]
# 2021-04-30 11:15:01,892 INFO:In study 2009/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1600  5578 10484 11640 12167]
# 2021-04-30 11:15:01,902 INFO:In study 2010/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1987 2028 4795 4916 9276]
# 2021-04-30 11:15:01,910 INFO:In study 2011/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2041  4458  5099  6061 10676]
# 2021-04-30 11:15:01,920 INFO:In study 2012/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1808  5843 11136 12722 13457]
# 2021-04-30 11:15:01,931 INFO:In study 2013/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 562 1171 1664 2129 9398]
# 2021-04-30 11:15:01,940 INFO:In study 2014/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  89 2101 3518 5469 9414]
# 2021-04-30 11:15:01,947 INFO:In study 2015/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2655  6577  6798  7854 11784]
# 2021-04-30 11:15:01,955 INFO:In study 2016/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2134 2910 4028 4059 4833]
# 2021-04-30 11:15:01,962 INFO:In study 2017/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1211 5555 7988 8570 9249]
# 2021-04-30 11:15:01,969 INFO:In study 2018/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1239 1567 6608 6944 8586]
# 2021-04-30 11:15:01,977 INFO:In study 2019/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4203  5607  8816  9534 10974]
# 2021-04-30 11:15:01,988 INFO:In study 2020/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2162  5663  7614 10027 14582]
# 2021-04-30 11:15:01,995 INFO:In study 2021/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 700 3395 6292 8957 9748]
# 2021-04-30 11:15:02,004 INFO:In study 2022/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1594  2011  3436  4236 10288]
# 2021-04-30 11:15:02,015 INFO:In study 2023/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  604  3816  8900 10450 12603]
# 2021-04-30 11:15:02,022 INFO:In study 2024/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1032  1230  5251 10255 11567]
# 2021-04-30 11:15:02,030 INFO:In study 2025/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1617 4557 5591 7291 9036]
# 2021-04-30 11:15:02,036 INFO:In study 2026/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  444  1668  8296 11157 11649]
# 2021-04-30 11:15:02,043 INFO:In study 2027/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2207 3262 4998 7009 7746]
# 2021-04-30 11:15:02,052 INFO:In study 2028/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [4105 5049 5711 5829 6081]
# 2021-04-30 11:15:02,063 INFO:In study 2029/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 493 1641 3334 6500 8334]
# 2021-04-30 11:15:02,074 INFO:In study 2030/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 7784  7869  7946 13800 14532]
# 2021-04-30 11:15:02,082 INFO:In study 2031/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2210 2544 3250 7207 7530]
# 2021-04-30 11:15:02,092 INFO:In study 2032/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [5051 8266 8472 9408 9606]
# 2021-04-30 11:15:02,102 INFO:In study 2033/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2132  4968  7568 10428 10912]
# 2021-04-30 11:15:02,114 INFO:In study 2034/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4410  6380  9682  9910 11760]
# 2021-04-30 11:15:02,125 INFO:In study 2035/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 526 2514 3521 3769 6531]
# 2021-04-30 11:15:02,136 INFO:In study 2036/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1257  1766  5810  5873 10461]
# 2021-04-30 11:15:02,146 INFO:In study 2037/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1874  2437  3531  8288 10671]
# 2021-04-30 11:15:02,158 INFO:In study 2038/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1487  1801  6255 10326 11715]
# 2021-04-30 11:15:02,166 INFO:In study 2039/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1066 3391 5026 5613 7533]
# 2021-04-30 11:15:02,175 INFO:In study 2040/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 4317 11204 11346 13016 13265]
# 2021-04-30 11:15:02,183 INFO:In study 2041/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3505 3682 4058 4330 6626]
# 2021-04-30 11:15:02,191 INFO:In study 2042/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 3962  7085  9565 10527 11489]
# 2021-04-30 11:15:02,200 INFO:In study 2043/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1540  5582 10493 14976 16818]
# 2021-04-30 11:15:02,208 INFO:In study 2044/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 1337  4291  4987 11549 11818]
# 2021-04-30 11:15:02,216 INFO:In study 2045/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [2954 3893 6227 6657 9385]
# 2021-04-30 11:15:02,227 INFO:In study 2046/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 868 5707 5782 5955 6834]
# 2021-04-30 11:15:02,235 INFO:In study 2047/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1798 2267 2979 3048 5177]
# 2021-04-30 11:15:02,243 INFO:In study 2048/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 5014  7112 10129 10134 11821]
# 2021-04-30 11:15:02,254 INFO:In study 2049/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  395   541  8007  8228 10017]
# 2021-04-30 11:15:02,265 INFO:In study 2050/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  28 3668 6590 9898 9932]
# 2021-04-30 11:15:02,275 INFO:In study 2051/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 293 1892 3041 5969 7290]
# 2021-04-30 11:15:02,284 INFO:In study 2052/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [3052 3055 3913 4110 4566]
# 2021-04-30 11:15:02,293 INFO:In study 2053/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [1037 2117 2258 5250 7395]
# 2021-04-30 11:15:02,305 INFO:In study 2054/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [  262   828  6619  6926 10465]
# 2021-04-30 11:15:02,315 INFO:In study 2055/2058, train on 20567 randomly selected points; then test on the other 10: first few test points = [ 2035  3281  5842 10923 11068]
# 2021-04-30 11:15:02,322 INFO:In study 2056/2058, train on 20568 randomly selected points; then test on the other 9: first few test points = [1127 1578 3105 3559 5594]
# 2021-04-30 11:15:02,329 INFO:In study 2057/2058, train on 20568 randomly selected points; then test on the other 9: first few test points = [ 3643  4276  7431  9619 11190]
# 2021-04-30 11:15:02,336 INFO:In study 2058/2058, train on 20568 randomly selected points; then test on the other 9: first few test points = [1282 2431 2682 3096 5428]

# %%
plot_kfold_scores(scores10)
